# %%
import pymongo 
from pymongo import MongoClient
import os 
from dotenv import load_dotenv, find_dotenv
import numpy as np
import pandas as pd

# %%
load_dotenv(find_dotenv())
my_password = os.environ.get("RAHUL_PASS")

documents = {}

# %%
try: 
    uri = f"mongodb+srv://rr1437:{my_password}@prometrics.h105zsq.mongodb.net/?retryWrites=true&w=majority&appName=ProMetrics"
    client = MongoClient(uri)

    database = client["main"]
    collection = database["test_gpu_metrics"]

    results = collection.find({"Time Delta" : 0})

    for index, result in enumerate(results):
        documents[index] = result
        print(index, result)

    client.close()


except Exception as e:
    raise Exception(
        "Recieved the following error:" + e
    )
# Out:
# 0 {'_id': ObjectId('685821f6ac1d6ac9e7afdde1'), 'GPU Utilization (%)': 0.0, 'Power Draw (Watts)': 23.64, 'Power Limit (Watts)': 250.0, 'GPU Temp (°C)': 21.0, 'GPU Current Clock (MHz)': 135000000.0, 'GPU Clock Limit (MHz)': 1380000000.0, 'Memory Current Clock (MHz)': 877000000.0, 'Memory Clock Limit (MHz)': 877000000.0, 'Memory Allocation Used (MB)': 5242880.0, 'Memory Allocation Total (MB)': 17179869184.0, 'Memory Utilization (%)': 0.0, 'GPU Info': 'Tesla V100-PCIE-16GB', 'Start Time': '11:32:06', 'Current Time': '11:32:06', 'Time Delta': 0, 'Test Stage': 'idle'}
# 1 {'_id': ObjectId('68582283f82fc7d43931d730'), 'GPU Utilization (%)': 0.0, 'Power Draw (Watts)': 23.54, 'Power Limit (Watts)': 250.0, 'GPU Temp (°C)': 21.0, 'GPU Current Clock (MHz)': 135000000.0, 'GPU Clock Limit (MHz)': 1380000000.0, 'Memory Current Clock (MHz)': 877000000.0, 'Memory Clock Limit (MHz)': 877000000.0, 'Memory Allocation Used (MB)': 5242880.0, 'Memory Allocation Total (MB)': 17179869184.0, 'Memory Utilization (%)': 0.0, 'GPU Info': 'Tesla V100-PCIE-16GB', 'Start Time': '11:34:26', 'Current Time': '11:34:27', 'Time Delta': 0, 'Test Stage': 'background'}
# 2 {'_id': ObjectId('68582391aaa9bc3b9ce58086'), 'GPU Utilization (%)': 0.0, 'Power Draw (Watts)': 23.64, 'Power Limit (Watts)': 250.0, 'GPU Temp (°C)': 21.0, 'GPU Current Clock (MHz)': 135000000.0, 'GPU Clock Limit (MHz)': 1380000000.0, 'Memory Current Clock (MHz)': 877000000.0, 'Memory Clock Limit (MHz)': 877000000.0, 'Memory Allocation Used (MB)': 9437184.0, 'Memory Allocation Total (MB)': 17179869184.0, 'Memory Utilization (%)': 0.0, 'GPU Info': 'Tesla V100-PCIE-16GB', 'Start Time': '11:38:57', 'Current Time': '11:38:57', 'Time Delta': 0, 'Test Stage': 'download'}
# 3 {'_id': ObjectId('685823c494a38d6eb066743f'), 'GPU Utilization (%)': 0.0, 'Power Draw (Watts)': 34.5, 'Power Limit (Watts)': 250.0, 'GPU Temp (°C)': 23.0, 'GPU Current Clock (MHz)': 1245000000.0, 'GPU Clock Limit (MHz)': 1380000000.0, 'Memory Current Clock (MHz)': 877000000.0, 'Memory Clock Limit (MHz)': 877000000.0, 'Memory Allocation Used (MB)': 6997147648.0, 'Memory Allocation Total (MB)': 17179869184.0, 'Memory Utilization (%)': 0.0, 'GPU Info': 'Tesla V100-PCIE-16GB', 'Start Time': '11:39:47', 'Current Time': '11:39:48', 'Time Delta': 0, 'Test Stage': 'interaction'}
# 4 {'_id': ObjectId('685823e391f8f8cd731146b3'), 'GPU Utilization (%)': 0.0, 'Power Draw (Watts)': 34.51, 'Power Limit (Watts)': 250.0, 'GPU Temp (°C)': 25.0, 'GPU Current Clock (MHz)': 1245000000.0, 'GPU Clock Limit (MHz)': 1380000000.0, 'Memory Current Clock (MHz)': 877000000.0, 'Memory Clock Limit (MHz)': 877000000.0, 'Memory Allocation Used (MB)': 7049576448.0, 'Memory Allocation Total (MB)': 17179869184.0, 'Memory Utilization (%)': 0.0, 'GPU Info': 'Tesla V100-PCIE-16GB', 'Start Time': '11:40:18', 'Current Time': '11:40:19', 'Time Delta': 0, 'Test Stage': 'interaction'}

# %%
documents = pd.DataFrame(documents)
documents = documents.T
documents.drop(columns=['_id'], inplace=True)

# %%
clock_speeds = ['GPU Current Clock (MHz)', 'GPU Clock Limit (MHz)', 'Memory Current Clock (MHz)', 'Memory Clock Limit (MHz)']
clock_speeds_c = ['GPU Current Clock (GHz)', 'GPU Clock Limit (GHz)', 'Memory Current Clock (GHz)', 'Memory Clock Limit (GHz)']
for i in clock_speeds:
    documents[i] = documents[i]/1000
    documents.rename(columns={i: clock_speeds_c[clock_speeds.index(i)]}, inplace=True)

# %%
documents
# Out:
#   GPU Utilization (%) Power Draw (Watts) Power Limit (Watts) GPU Temp (°C)  \
# 0                 0.0              23.64               250.0          21.0
# 1                 0.0              23.54               250.0          21.0
# 2                 0.0              23.64               250.0          21.0
# 3                 0.0               34.5               250.0          23.0
# 4                 0.0              34.51               250.0          25.0
#
#   GPU Current Clock (GHz) GPU Clock Limit (GHz) Memory Current Clock (GHz)  \
# 0                135000.0             1380000.0                   877000.0
# 1                135000.0             1380000.0                   877000.0
# 2                135000.0             1380000.0                   877000.0
# 3               1245000.0             1380000.0                   877000.0
# 4               1245000.0             1380000.0                   877000.0
#
#   Memory Clock Limit (GHz) Memory Allocation Used (MB)  \
# 0                 877000.0                   5242880.0
# 1                 877000.0                   5242880.0
# 2                 877000.0                   9437184.0
# 3                 877000.0                6997147648.0
# 4                 877000.0                7049576448.0
#
#   Memory Allocation Total (MB) Memory Utilization (%)              GPU Info  \
# 0                17179869184.0                    0.0  Tesla V100-PCIE-16GB
# 1                17179869184.0                    0.0  Tesla V100-PCIE-16GB
# 2                17179869184.0                    0.0  Tesla V100-PCIE-16GB
# 3                17179869184.0                    0.0  Tesla V100-PCIE-16GB
# 4                17179869184.0                    0.0  Tesla V100-PCIE-16GB
#
#   Start Time Current Time Time Delta   Test Stage
# 0   11:32:06     11:32:06          0         idle
# 1   11:34:26     11:34:27          0   background
# 2   11:38:57     11:38:57          0     download
# 3   11:39:47     11:39:48          0  interaction
# 4   11:40:18     11:40:19          0  interaction
