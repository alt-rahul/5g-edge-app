# %%
import pymongo 
from pymongo import MongoClient
import os 
from dotenv import load_dotenv, find_dotenv
import numpy as np
import pandas as pd

# %%
load_dotenv(find_dotenv())
my_password = os.environ.get("RAHUL_PASS")

documents = {}

# %%
try: 
    uri = f"mongodb+srv://rr1437:{my_password}@prometrics.h105zsq.mongodb.net/?retryWrites=true&w=majority&appName=ProMetrics"
    client = MongoClient(uri)

    database = client["main"]
    collection = database["test_gpu_metrics"]

    results = collection.find({"Time Delta" : 0})

    for index, result in enumerate(results):
        documents[index] = result

    client.close()


except Exception as e:
    raise Exception(
        "Recieved the following error:" + e
    )

# %%
documents = pd.DataFrame(documents)
documents.head()
# Out:
#                                             0                         1  \
# _id                  685821f6ac1d6ac9e7afdde1  68582283f82fc7d43931d730
# GPU Utilization (%)                       0.0                       0.0
# Power Draw (Watts)                      23.64                     23.54
# Power Limit (Watts)                     250.0                     250.0
# GPU Temp (°C)                            21.0                      21.0
#
#                                             2                         3  \
# _id                  68582391aaa9bc3b9ce58086  685823c494a38d6eb066743f
# GPU Utilization (%)                       0.0                       0.0
# Power Draw (Watts)                      23.64                      34.5
# Power Limit (Watts)                     250.0                     250.0
# GPU Temp (°C)                            21.0                      23.0
#
#                                             4
# _id                  685823e391f8f8cd731146b3
# GPU Utilization (%)                       0.0
# Power Draw (Watts)                      34.51
# Power Limit (Watts)                     250.0
# GPU Temp (°C)                            25.0
